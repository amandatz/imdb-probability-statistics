# %% [markdown]
# <a href="https://colab.research.google.com/github/amandatz/imdb-probability-statistics/blob/main/imdb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IMDB Movies Dataset

# %%
library(ggplot2)
library(readr)
library(tidyr)

# %% [markdown]
# ## Importar dados

# %%
url <- "https://raw.githubusercontent.com/amandatz/imdb-probability-statistics/main/data/imdb_top_1000.csv"
dados <- read.csv(url, sep = ",", header = TRUE)
dados$Gross <- as.numeric(gsub(",", "", dados$Gross))

# %% [markdown]
# ## Quantidade de filmes x Gênero

# %%
dados_separados <- dados %>%
  separate_rows(Genre, sep = ", ")

ggplot(dados_separados, aes(x = Genre)) +
  geom_bar(fill = "purple", alpha = 0.7) +
  labs(title = "Quantidade de Filmes por Gênero",
       x = "Gênero",
       y = "Quantidade de Filmes") +
  theme_minimal() +
  coord_flip()
# Out:
# plot without title
